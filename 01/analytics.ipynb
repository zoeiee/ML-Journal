# %%
import numpy as np
a = np.array([1,2,3,4])
a[1]
# Out:
# np.int64(2)

# %%
a = np.array([1, 2, 3, 4])
b = np.array([0, .5, 1, 1.5, 2])
a[::2]
# Out:
# array([1, 3])

# %%
A = np.array([
#.   0. 1. 2
    [1, 2, 3], # 0
    [4, 5, 6], # 1
    [7, 8, 9]  # 2
])
A[1][0]
# Out:
# array([4, 5, 6])

# %%
import pandas as pd
